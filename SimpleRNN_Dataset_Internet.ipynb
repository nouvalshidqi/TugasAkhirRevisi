# %%
from google.colab import drive
drive.mount('/content/gdrive')
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
from sklearn.preprocessing import LabelEncoder
import nltk
from sklearn.model_selection import train_test_split
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import BatchNormalization
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

import time

import warnings
warnings.filterwarnings("ignore")
# Out:
# Mounted at /content/gdrive

# %%
df_data = pd.read_csv('gdrive/My Drive/TA/Copy of DoS.csv')
df_data.head()
# Out:
#    frame.time_delta  frame.time_delta_displayed  ...  mqtt.willtopic_len    type
# 0          0.000000                    0.000000  ...                 NaN  normal
# 1          0.001922                    0.001922  ...                 NaN  normal
# 2          0.001010                    0.001010  ...                 NaN  normal
# 3          0.008597                    0.008597  ...                 NaN  normal
# 4          0.002925                    0.002925  ...                 NaN  normal
#
# [5 rows x 67 columns]

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94625 entries, 0 to 94624
# Data columns (total 67 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   frame.time_delta            94625 non-null  float64
#  1   frame.time_delta_displayed  94625 non-null  float64
#  2   frame.time_epoch            94625 non-null  float64
#  3   frame.time_invalid          0 non-null      float64
#  4   frame.time_relative         94625 non-null  float64
#  5   ip.src                      93592 non-null  object
#  6   ip.dst                      93592 non-null  object
#  7   tcp.srcport                 88460 non-null  float64
#  8   tcp.dstport                 88460 non-null  float64
#  9   eth.src                     94625 non-null  object
#  10  eth.dst                     94625 non-null  object
#  11  frame.cap_len               94625 non-null  int64
#  12  frame.coloring_rule.name    0 non-null      float64
#  13  frame.coloring_rule.string  0 non-null      float64
#  14  frame.comment               0 non-null      float64
#  15  frame.comment.expert        0 non-null      float64
#  16  frame.encap_type            94625 non-null  int64
#  17  frame.file_off              0 non-null      float64
#  18  frame.ignored               94625 non-null  int64
#  19  frame.incomplete            0 non-null      float64
#  20  frame.interface_id          0 non-null      float64
#  21  frame.interface_name        0 non-null      float64
#  22  frame.len                   94625 non-null  int64
#  23  frame.link_nr               0 non-null      float64
#  24  frame.marked                94625 non-null  int64
#  25  frame.md5_hash              0 non-null      float64
#  26  frame.number                94625 non-null  int64
#  27  frame.offset_shift          94625 non-null  float64
#  28  mqtt.clientid               323 non-null    object
#  29  mqtt.clientid_len           323 non-null    float64
#  30  mqtt.conack.flags           770 non-null    object
#  31  mqtt.conack.flags.reserved  770 non-null    float64
#  32  mqtt.conack.flags.sp        770 non-null    float64
#  33  mqtt.conack.val             770 non-null    float64
#  34  mqtt.conflag.cleansess      323 non-null    float64
#  35  mqtt.conflag.passwd         323 non-null    float64
#  36  mqtt.conflag.qos            323 non-null    float64
#  37  mqtt.conflag.reserved       323 non-null    float64
#  38  mqtt.conflag.retain         323 non-null    float64
#  39  mqtt.conflag.uname          323 non-null    float64
#  40  mqtt.conflag.willflag       323 non-null    float64
#  41  mqtt.conflags               323 non-null    object
#  42  mqtt.dupflag                38464 non-null  float64
#  43  mqtt.hdrflags               39535 non-null  object
#  44  mqtt.kalive                 323 non-null    float64
#  45  mqtt.len                    39535 non-null  float64
#  46  mqtt.msg                    37733 non-null  object
#  47  mqtt.msgid                  791 non-null    float64
#  48  mqtt.msgtype                39535 non-null  float64
#  49  mqtt.passwd                 0 non-null      float64
#  50  mqtt.passwd_len             0 non-null      float64
#  51  mqtt.proto_len              323 non-null    float64
#  52  mqtt.protoname              323 non-null    object
#  53  mqtt.qos                    38464 non-null  float64
#  54  mqtt.retain                 38464 non-null  float64
#  55  mqtt.sub.qos                4 non-null      float64
#  56  mqtt.suback.qos             4 non-null      float64
#  57  mqtt.topic                  37737 non-null  object
#  58  mqtt.topic_len              38468 non-null  float64
#  59  mqtt.username               0 non-null      float64
#  60  mqtt.username_len           0 non-null      float64
#  61  mqtt.ver                    323 non-null    float64
#  62  mqtt.willmsg                0 non-null      float64
#  63  mqtt.willmsg_len            0 non-null      float64
#  64  mqtt.willtopic              0 non-null      float64
#  65  mqtt.willtopic_len          0 non-null      float64
#  66  type                        94625 non-null  object
# dtypes: float64(49), int64(6), object(12)
# memory usage: 48.4+ MB

# %%
print (df_data.isnull().sum())
# Out:
# frame.time_delta                  0
# frame.time_delta_displayed        0
# frame.time_epoch                  0
# frame.time_invalid            94625
# frame.time_relative               0
#                               ...
# mqtt.willmsg                  94625
# mqtt.willmsg_len              94625
# mqtt.willtopic                94625
# mqtt.willtopic_len            94625
# type                              0
# Length: 67, dtype: int64

# %%
df_data.drop(['frame.time_invalid','frame.coloring_rule.name', 'frame.coloring_rule.string', 'frame.comment', 'frame.comment.expert', 'frame.file_off', 'frame.incomplete', 'frame.interface_id', 'frame.interface_name', 'frame.link_nr', 'frame.md5_hash', 'mqtt.passwd', 'mqtt.passwd_len', 'mqtt.username', 'mqtt.username_len', 'mqtt.willmsg', 'mqtt.willmsg_len', 'mqtt.willtopic', 'mqtt.willtopic_len'], axis=1, inplace = True)
print (df_data.isnull().sum())
# Out:
# frame.time_delta                  0
# frame.time_delta_displayed        0
# frame.time_epoch                  0
# frame.time_relative               0
# ip.src                         1033
# ip.dst                         1033
# tcp.srcport                    6165
# tcp.dstport                    6165
# eth.src                           0
# eth.dst                           0
# frame.cap_len                     0
# frame.encap_type                  0
# frame.ignored                     0
# frame.len                         0
# frame.marked                      0
# frame.number                      0
# frame.offset_shift                0
# mqtt.clientid                 94302
# mqtt.clientid_len             94302
# mqtt.conack.flags             93855
# mqtt.conack.flags.reserved    93855
# mqtt.conack.flags.sp          93855
# mqtt.conack.val               93855
# mqtt.conflag.cleansess        94302
# mqtt.conflag.passwd           94302
# mqtt.conflag.qos              94302
# mqtt.conflag.reserved         94302
# mqtt.conflag.retain           94302
# mqtt.conflag.uname            94302
# mqtt.conflag.willflag         94302
# mqtt.conflags                 94302
# mqtt.dupflag                  56161
# mqtt.hdrflags                 55090
# mqtt.kalive                   94302
# mqtt.len                      55090
# mqtt.msg                      56892
# mqtt.msgid                    93834
# mqtt.msgtype                  55090
# mqtt.proto_len                94302
# mqtt.protoname                94302
# mqtt.qos                      56161
# mqtt.retain                   56161
# mqtt.sub.qos                  94621
# mqtt.suback.qos               94621
# mqtt.topic                    56888
# mqtt.topic_len                56157
# mqtt.ver                      94302
# type                              0
# dtype: int64

# %%
df_data.drop(['mqtt.clientid','mqtt.clientid_len', 'mqtt.conack.flags', 'mqtt.conack.flags.reserved', 'mqtt.conack.flags.sp', 'mqtt.conack.val', 'mqtt.conflag.cleansess', 'mqtt.conflag.passwd', 'mqtt.conflag.qos', 'mqtt.conflag.reserved', 'mqtt.conflag.retain', 'mqtt.conflag.uname', 'mqtt.conflag.willflag', 'mqtt.conflags', 'mqtt.kalive', 'mqtt.msgid', 'mqtt.proto_len', 'mqtt.protoname', 'mqtt.sub.qos', 'mqtt.suback.qos', 'mqtt.ver'], axis=1, inplace = True)
print (df_data.isnull().sum())
# Out:
# frame.time_delta                  0
# frame.time_delta_displayed        0
# frame.time_epoch                  0
# frame.time_relative               0
# ip.src                         1033
# ip.dst                         1033
# tcp.srcport                    6165
# tcp.dstport                    6165
# eth.src                           0
# eth.dst                           0
# frame.cap_len                     0
# frame.encap_type                  0
# frame.ignored                     0
# frame.len                         0
# frame.marked                      0
# frame.number                      0
# frame.offset_shift                0
# mqtt.dupflag                  56161
# mqtt.hdrflags                 55090
# mqtt.len                      55090
# mqtt.msg                      56892
# mqtt.msgtype                  55090
# mqtt.qos                      56161
# mqtt.retain                   56161
# mqtt.topic                    56888
# mqtt.topic_len                56157
# type                              0
# dtype: int64

# %%
le = LabelEncoder()
 
df_data['type']= le.fit_transform(df_data['type'])
df_data['frame.encap_type']= le.fit_transform(df_data['frame.encap_type'])

print(df_data['type'])
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 94620    1
# 94621    1
# 94622    1
# 94623    1
# 94624    1
# Name: type, Length: 94625, dtype: int64

# %%
df_data['ip.src'] = df_data['ip.src'].fillna(df_data['ip.src'].mode()[0])
df_data['ip.dst'] = df_data['ip.dst'].fillna(df_data['ip.dst'].mode()[0])
df_data['tcp.srcport'] = df_data['tcp.srcport'].fillna(df_data['tcp.srcport'].mean())
df_data['tcp.dstport'] = df_data['tcp.dstport'].fillna(df_data['tcp.dstport'].mean())
df_data['mqtt.dupflag'] = df_data['mqtt.dupflag'].fillna(0)
df_data['mqtt.hdrflags'] = df_data['mqtt.hdrflags'].fillna(0)
df_data['mqtt.len'] = df_data['mqtt.len'].fillna(0)
df_data['mqtt.msg'] = df_data['mqtt.msg'].fillna(0)
df_data['mqtt.msgtype'] = df_data['mqtt.msgtype'].fillna(0)
df_data['mqtt.qos'] = df_data['mqtt.qos'].fillna(0)
df_data['mqtt.retain'] = df_data['mqtt.retain'].fillna(0)
df_data['mqtt.topic'] = df_data['mqtt.topic'].fillna(0)
df_data['mqtt.topic_len'] = df_data['mqtt.topic_len'].fillna(0)

print(df_data.isna().sum())
# Out:
# frame.time_delta              0
# frame.time_delta_displayed    0
# frame.time_epoch              0
# frame.time_relative           0
# ip.src                        0
# ip.dst                        0
# tcp.srcport                   0
# tcp.dstport                   0
# eth.src                       0
# eth.dst                       0
# frame.cap_len                 0
# frame.encap_type              0
# frame.ignored                 0
# frame.len                     0
# frame.marked                  0
# frame.number                  0
# frame.offset_shift            0
# mqtt.dupflag                  0
# mqtt.hdrflags                 0
# mqtt.len                      0
# mqtt.msg                      0
# mqtt.msgtype                  0
# mqtt.qos                      0
# mqtt.retain                   0
# mqtt.topic                    0
# mqtt.topic_len                0
# type                          0
# dtype: int64

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94625 entries, 0 to 94624
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   frame.time_delta            94625 non-null  float64
#  1   frame.time_delta_displayed  94625 non-null  float64
#  2   frame.time_epoch            94625 non-null  float64
#  3   frame.time_relative         94625 non-null  float64
#  4   ip.src                      94625 non-null  object
#  5   ip.dst                      94625 non-null  object
#  6   tcp.srcport                 94625 non-null  float64
#  7   tcp.dstport                 94625 non-null  float64
#  8   eth.src                     94625 non-null  object
#  9   eth.dst                     94625 non-null  object
#  10  frame.cap_len               94625 non-null  int64
#  11  frame.encap_type            94625 non-null  int64
#  12  frame.ignored               94625 non-null  int64
#  13  frame.len                   94625 non-null  int64
#  14  frame.marked                94625 non-null  int64
#  15  frame.number                94625 non-null  int64
#  16  frame.offset_shift          94625 non-null  float64
#  17  mqtt.dupflag                94625 non-null  float64
#  18  mqtt.hdrflags               94625 non-null  object
#  19  mqtt.len                    94625 non-null  float64
#  20  mqtt.msg                    94625 non-null  object
#  21  mqtt.msgtype                94625 non-null  float64
#  22  mqtt.qos                    94625 non-null  float64
#  23  mqtt.retain                 94625 non-null  float64
#  24  mqtt.topic                  94625 non-null  object
#  25  mqtt.topic_len              94625 non-null  float64
#  26  type                        94625 non-null  int64
# dtypes: float64(13), int64(7), object(7)
# memory usage: 19.5+ MB

# %%
df_data['ip.src'] = df_data['ip.src'].apply(pd.to_numeric, errors='coerce')
df_data['ip.dst'] = df_data['ip.dst'].apply(pd.to_numeric, errors='coerce')
df_data['eth.src'] = df_data['eth.src'].apply(pd.to_numeric, errors='coerce')
df_data['eth.dst'] = df_data['eth.dst'].apply(pd.to_numeric, errors='coerce')
df_data['mqtt.hdrflags'] = df_data['mqtt.hdrflags'].apply(pd.to_numeric, errors='coerce')
df_data['mqtt.msg'] = df_data['mqtt.msg'].apply(pd.to_numeric, errors='coerce')
df_data['mqtt.topic'] = df_data['mqtt.topic'].apply(pd.to_numeric, errors='coerce')

df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94625 entries, 0 to 94624
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   frame.time_delta            94625 non-null  float64
#  1   frame.time_delta_displayed  94625 non-null  float64
#  2   frame.time_epoch            94625 non-null  float64
#  3   frame.time_relative         94625 non-null  float64
#  4   ip.src                      0 non-null      float64
#  5   ip.dst                      0 non-null      float64
#  6   tcp.srcport                 94625 non-null  float64
#  7   tcp.dstport                 94625 non-null  float64
#  8   eth.src                     0 non-null      float64
#  9   eth.dst                     0 non-null      float64
#  10  frame.cap_len               94625 non-null  int64
#  11  frame.encap_type            94625 non-null  int64
#  12  frame.ignored               94625 non-null  int64
#  13  frame.len                   94625 non-null  int64
#  14  frame.marked                94625 non-null  int64
#  15  frame.number                94625 non-null  int64
#  16  frame.offset_shift          94625 non-null  float64
#  17  mqtt.dupflag                94625 non-null  float64
#  18  mqtt.hdrflags               55090 non-null  float64
#  19  mqtt.len                    94625 non-null  float64
#  20  mqtt.msg                    57132 non-null  float64
#  21  mqtt.msgtype                94625 non-null  float64
#  22  mqtt.qos                    94625 non-null  float64
#  23  mqtt.retain                 94625 non-null  float64
#  24  mqtt.topic                  56888 non-null  float64
#  25  mqtt.topic_len              94625 non-null  float64
#  26  type                        94625 non-null  int64
# dtypes: float64(20), int64(7)
# memory usage: 19.5 MB

# %%
print(df_data.isna().sum())
# Out:
# frame.time_delta                  0
# frame.time_delta_displayed        0
# frame.time_epoch                  0
# frame.time_relative               0
# ip.src                        94625
# ip.dst                        94625
# tcp.srcport                       0
# tcp.dstport                       0
# eth.src                       94625
# eth.dst                       94625
# frame.cap_len                     0
# frame.encap_type                  0
# frame.ignored                     0
# frame.len                         0
# frame.marked                      0
# frame.number                      0
# frame.offset_shift                0
# mqtt.dupflag                      0
# mqtt.hdrflags                 39535
# mqtt.len                          0
# mqtt.msg                      37493
# mqtt.msgtype                      0
# mqtt.qos                          0
# mqtt.retain                       0
# mqtt.topic                    37737
# mqtt.topic_len                    0
# type                              0
# dtype: int64

# %%
df_data.drop(['ip.src', 'ip.dst', 'eth.src', 'eth.dst'], axis=1, inplace = True)
print(df_data.isna().sum())
# Out:
# frame.time_delta                  0
# frame.time_delta_displayed        0
# frame.time_epoch                  0
# frame.time_relative               0
# tcp.srcport                       0
# tcp.dstport                       0
# frame.cap_len                     0
# frame.encap_type                  0
# frame.ignored                     0
# frame.len                         0
# frame.marked                      0
# frame.number                      0
# frame.offset_shift                0
# mqtt.dupflag                      0
# mqtt.hdrflags                 39535
# mqtt.len                          0
# mqtt.msg                      37493
# mqtt.msgtype                      0
# mqtt.qos                          0
# mqtt.retain                       0
# mqtt.topic                    37737
# mqtt.topic_len                    0
# type                              0
# dtype: int64

# %%
df_data['mqtt.hdrflags'] = df_data['mqtt.hdrflags'].fillna(df_data['mqtt.hdrflags'].mean())
df_data['mqtt.msg'] = df_data['mqtt.msg'].fillna(df_data['mqtt.msg'].mean())
df_data['mqtt.topic'] = df_data['mqtt.topic'].fillna(df_data['mqtt.topic'].mean())

print(df_data.isna().sum())
# Out:
# frame.time_delta              0
# frame.time_delta_displayed    0
# frame.time_epoch              0
# frame.time_relative           0
# tcp.srcport                   0
# tcp.dstport                   0
# frame.cap_len                 0
# frame.encap_type              0
# frame.ignored                 0
# frame.len                     0
# frame.marked                  0
# frame.number                  0
# frame.offset_shift            0
# mqtt.dupflag                  0
# mqtt.hdrflags                 0
# mqtt.len                      0
# mqtt.msg                      0
# mqtt.msgtype                  0
# mqtt.qos                      0
# mqtt.retain                   0
# mqtt.topic                    0
# mqtt.topic_len                0
# type                          0
# dtype: int64

# %%
df_data
# Out:
#        frame.time_delta  frame.time_delta_displayed  ...  mqtt.topic_len  type
# 0              0.000000                    0.000000  ...             0.0     1
# 1              0.001922                    0.001922  ...             0.0     1
# 2              0.001010                    0.001010  ...             0.0     1
# 3              0.008597                    0.008597  ...             0.0     1
# 4              0.002925                    0.002925  ...             0.0     1
# ...                 ...                         ...  ...             ...   ...
# 94620          0.000097                    0.000097  ...             0.0     1
# 94621          0.001754                    0.001754  ...             0.0     1
# 94622          0.001133                    0.001133  ...             0.0     1
# 94623          0.000074                    0.000074  ...             0.0     1
# 94624          0.057908                    0.057908  ...             0.0     1
#
# [94625 rows x 23 columns]

# %%
x = df_data.drop(['type'], axis = 1)
x.head()
# Out:
#    frame.time_delta  frame.time_delta_displayed  ...  mqtt.topic  mqtt.topic_len
# 0          0.000000                    0.000000  ...         0.0             0.0
# 1          0.001922                    0.001922  ...         0.0             0.0
# 2          0.001010                    0.001010  ...         0.0             0.0
# 3          0.008597                    0.008597  ...         0.0             0.0
# 4          0.002925                    0.002925  ...         0.0             0.0
#
# [5 rows x 22 columns]

# %%
sc_X = StandardScaler()
x = sc_X.fit_transform(x)

# %%
y = df_data['type']
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: type, dtype: int64

# %%
from collections import Counter
counter = Counter(y)
print(counter)
# Out:
# Counter({1: 49111, 0: 45514})

# %%
from imblearn.over_sampling import SMOTE
# transform the dataset
oversample = SMOTE()
x, y = oversample.fit_resample(x, y)

# %%
from collections import Counter
counter = Counter(y)
print(counter)
# Out:
# Counter({1: 49111, 0: 49111})

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state= 100)

# %%
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
model = Sequential()
model.add(SimpleRNN(128, input_shape=(X_train.shape[1], X_train.shape[2]) ,return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.summary()
model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])
model.fit(X_train, y_train, epochs=50, batch_size=72, verbose=1, validation_data=(X_test, y_test), shuffle=False)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 128)               19328
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 19,457
# Trainable params: 19,457
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1092/1092 [==============================] - 6s 4ms/step - loss: 0.1775 - accuracy: 0.9348 - val_loss: 0.1253 - val_accuracy: 0.9501
# Epoch 2/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1297 - accuracy: 0.9511 - val_loss: 0.1177 - val_accuracy: 0.9490
# Epoch 3/50
# 1092/1092 [==============================] - 4s 3ms/step - loss: 0.1252 - accuracy: 0.9539 - val_loss: 0.1143 - val_accuracy: 0.9517
# Epoch 4/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1233 - accuracy: 0.9542 - val_loss: 0.1127 - val_accuracy: 0.9549
# Epoch 5/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1222 - accuracy: 0.9544 - val_loss: 0.1116 - val_accuracy: 0.9511
# Epoch 6/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1211 - accuracy: 0.9552 - val_loss: 0.1100 - val_accuracy: 0.9620
# Epoch 7/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1201 - accuracy: 0.9560 - val_loss: 0.1087 - val_accuracy: 0.9648
# Epoch 8/50
# 1092/1092 [==============================] - 4s 3ms/step - loss: 0.1194 - accuracy: 0.9557 - val_loss: 0.1085 - val_accuracy: 0.9585
# Epoch 9/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1189 - accuracy: 0.9562 - val_loss: 0.1070 - val_accuracy: 0.9637
# Epoch 10/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1181 - accuracy: 0.9557 - val_loss: 0.1065 - val_accuracy: 0.9596
# Epoch 11/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1164 - accuracy: 0.9563 - val_loss: 0.1050 - val_accuracy: 0.9650
# Epoch 12/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1160 - accuracy: 0.9566 - val_loss: 0.1038 - val_accuracy: 0.9633
# Epoch 13/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1145 - accuracy: 0.9573 - val_loss: 0.1012 - val_accuracy: 0.9654
# Epoch 14/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1130 - accuracy: 0.9571 - val_loss: 0.1007 - val_accuracy: 0.9657
# Epoch 15/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1118 - accuracy: 0.9573 - val_loss: 0.0976 - val_accuracy: 0.9649
# Epoch 16/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1111 - accuracy: 0.9579 - val_loss: 0.0972 - val_accuracy: 0.9654
# Epoch 17/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1096 - accuracy: 0.9586 - val_loss: 0.0960 - val_accuracy: 0.9658
# Epoch 18/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1085 - accuracy: 0.9588 - val_loss: 0.0935 - val_accuracy: 0.9658
# Epoch 19/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1077 - accuracy: 0.9595 - val_loss: 0.0933 - val_accuracy: 0.9672
# Epoch 20/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1069 - accuracy: 0.9593 - val_loss: 0.0904 - val_accuracy: 0.9657
# Epoch 21/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.1056 - accuracy: 0.9592 - val_loss: 0.0881 - val_accuracy: 0.9660
# Epoch 22/50
# 1092/1092 [==============================] - 4s 3ms/step - loss: 0.1024 - accuracy: 0.9607 - val_loss: 0.0862 - val_accuracy: 0.9673
# Epoch 23/50
# 1092/1092 [==============================] - 4s 3ms/step - loss: 0.1011 - accuracy: 0.9607 - val_loss: 0.0828 - val_accuracy: 0.9697
# Epoch 24/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0992 - accuracy: 0.9613 - val_loss: 0.0812 - val_accuracy: 0.9686
# Epoch 25/50
# 1092/1092 [==============================] - 4s 3ms/step - loss: 0.0974 - accuracy: 0.9625 - val_loss: 0.0791 - val_accuracy: 0.9699
# Epoch 26/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0953 - accuracy: 0.9629 - val_loss: 0.0758 - val_accuracy: 0.9756
# Epoch 27/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0934 - accuracy: 0.9637 - val_loss: 0.0738 - val_accuracy: 0.9741
# Epoch 28/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0912 - accuracy: 0.9643 - val_loss: 0.0698 - val_accuracy: 0.9749
# Epoch 29/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0889 - accuracy: 0.9654 - val_loss: 0.0666 - val_accuracy: 0.9753
# Epoch 30/50
# 1092/1092 [==============================] - 4s 3ms/step - loss: 0.0863 - accuracy: 0.9678 - val_loss: 0.0654 - val_accuracy: 0.9768
# Epoch 31/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0848 - accuracy: 0.9677 - val_loss: 0.0611 - val_accuracy: 0.9777
# Epoch 32/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0827 - accuracy: 0.9689 - val_loss: 0.0603 - val_accuracy: 0.9786
# Epoch 33/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0811 - accuracy: 0.9685 - val_loss: 0.0577 - val_accuracy: 0.9788
# Epoch 34/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0791 - accuracy: 0.9702 - val_loss: 0.0562 - val_accuracy: 0.9790
# Epoch 35/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0777 - accuracy: 0.9710 - val_loss: 0.0536 - val_accuracy: 0.9793
# Epoch 36/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0755 - accuracy: 0.9719 - val_loss: 0.0526 - val_accuracy: 0.9799
# Epoch 37/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0749 - accuracy: 0.9715 - val_loss: 0.0506 - val_accuracy: 0.9796
# Epoch 38/50
# 1092/1092 [==============================] - 4s 3ms/step - loss: 0.0730 - accuracy: 0.9730 - val_loss: 0.0489 - val_accuracy: 0.9816
# Epoch 39/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0731 - accuracy: 0.9727 - val_loss: 0.0479 - val_accuracy: 0.9820
# Epoch 40/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0718 - accuracy: 0.9725 - val_loss: 0.0471 - val_accuracy: 0.9819
# Epoch 41/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0693 - accuracy: 0.9742 - val_loss: 0.0456 - val_accuracy: 0.9826
# Epoch 42/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0693 - accuracy: 0.9738 - val_loss: 0.0448 - val_accuracy: 0.9829
# Epoch 43/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0684 - accuracy: 0.9744 - val_loss: 0.0435 - val_accuracy: 0.9837
# Epoch 44/50
# 1092/1092 [==============================] - 5s 4ms/step - loss: 0.0688 - accuracy: 0.9745 - val_loss: 0.0433 - val_accuracy: 0.9834
# Epoch 45/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0662 - accuracy: 0.9751 - val_loss: 0.0417 - val_accuracy: 0.9851
# Epoch 46/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0644 - accuracy: 0.9759 - val_loss: 0.0413 - val_accuracy: 0.9838
# Epoch 47/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0645 - accuracy: 0.9758 - val_loss: 0.0413 - val_accuracy: 0.9836
# Epoch 48/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0620 - accuracy: 0.9773 - val_loss: 0.0388 - val_accuracy: 0.9860
# Epoch 49/50
# 1092/1092 [==============================] - 4s 4ms/step - loss: 0.0633 - accuracy: 0.9758 - val_loss: 0.0380 - val_accuracy: 0.9878
# Epoch 50/50
# 1092/1092 [==============================] - 4s 3ms/step - loss: 0.0622 - accuracy: 0.9767 - val_loss: 0.0375 - val_accuracy: 0.9856

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(y_pred)
# Out:
# [[False]
#  [False]
#  [ True]
#  ...
#  [False]
#  [False]
#  [False]]

# %%
y_pred = y_pred[:, 0]
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred)
print('Recall: %f' % recall)
# Out:
# Accuracy: 0.985594
# Precision: 0.979817
# Recall: 0.991667
