# %%
from google.colab import drive
drive.mount('/content/gdrive')
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
from sklearn.preprocessing import LabelEncoder
import nltk
from sklearn.model_selection import train_test_split
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import GRU
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import BatchNormalization
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

import time

import warnings
warnings.filterwarnings("ignore")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df_data = pd.read_csv('gdrive/My Drive/TA/Copy of DoS.csv')
df_data.head()
# Out:
#    frame.time_delta  frame.time_delta_displayed  ...  mqtt.willtopic_len    type
# 0          0.000000                    0.000000  ...                 NaN  normal
# 1          0.001922                    0.001922  ...                 NaN  normal
# 2          0.001010                    0.001010  ...                 NaN  normal
# 3          0.008597                    0.008597  ...                 NaN  normal
# 4          0.002925                    0.002925  ...                 NaN  normal
#
# [5 rows x 67 columns]

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94625 entries, 0 to 94624
# Data columns (total 67 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   frame.time_delta            94625 non-null  float64
#  1   frame.time_delta_displayed  94625 non-null  float64
#  2   frame.time_epoch            94625 non-null  float64
#  3   frame.time_invalid          0 non-null      float64
#  4   frame.time_relative         94625 non-null  float64
#  5   ip.src                      93592 non-null  object
#  6   ip.dst                      93592 non-null  object
#  7   tcp.srcport                 88460 non-null  float64
#  8   tcp.dstport                 88460 non-null  float64
#  9   eth.src                     94625 non-null  object
#  10  eth.dst                     94625 non-null  object
#  11  frame.cap_len               94625 non-null  int64
#  12  frame.coloring_rule.name    0 non-null      float64
#  13  frame.coloring_rule.string  0 non-null      float64
#  14  frame.comment               0 non-null      float64
#  15  frame.comment.expert        0 non-null      float64
#  16  frame.encap_type            94625 non-null  int64
#  17  frame.file_off              0 non-null      float64
#  18  frame.ignored               94625 non-null  int64
#  19  frame.incomplete            0 non-null      float64
#  20  frame.interface_id          0 non-null      float64
#  21  frame.interface_name        0 non-null      float64
#  22  frame.len                   94625 non-null  int64
#  23  frame.link_nr               0 non-null      float64
#  24  frame.marked                94625 non-null  int64
#  25  frame.md5_hash              0 non-null      float64
#  26  frame.number                94625 non-null  int64
#  27  frame.offset_shift          94625 non-null  float64
#  28  mqtt.clientid               323 non-null    object
#  29  mqtt.clientid_len           323 non-null    float64
#  30  mqtt.conack.flags           770 non-null    object
#  31  mqtt.conack.flags.reserved  770 non-null    float64
#  32  mqtt.conack.flags.sp        770 non-null    float64
#  33  mqtt.conack.val             770 non-null    float64
#  34  mqtt.conflag.cleansess      323 non-null    float64
#  35  mqtt.conflag.passwd         323 non-null    float64
#  36  mqtt.conflag.qos            323 non-null    float64
#  37  mqtt.conflag.reserved       323 non-null    float64
#  38  mqtt.conflag.retain         323 non-null    float64
#  39  mqtt.conflag.uname          323 non-null    float64
#  40  mqtt.conflag.willflag       323 non-null    float64
#  41  mqtt.conflags               323 non-null    object
#  42  mqtt.dupflag                38464 non-null  float64
#  43  mqtt.hdrflags               39535 non-null  object
#  44  mqtt.kalive                 323 non-null    float64
#  45  mqtt.len                    39535 non-null  float64
#  46  mqtt.msg                    37733 non-null  object
#  47  mqtt.msgid                  791 non-null    float64
#  48  mqtt.msgtype                39535 non-null  float64
#  49  mqtt.passwd                 0 non-null      float64
#  50  mqtt.passwd_len             0 non-null      float64
#  51  mqtt.proto_len              323 non-null    float64
#  52  mqtt.protoname              323 non-null    object
#  53  mqtt.qos                    38464 non-null  float64
#  54  mqtt.retain                 38464 non-null  float64
#  55  mqtt.sub.qos                4 non-null      float64
#  56  mqtt.suback.qos             4 non-null      float64
#  57  mqtt.topic                  37737 non-null  object
#  58  mqtt.topic_len              38468 non-null  float64
#  59  mqtt.username               0 non-null      float64
#  60  mqtt.username_len           0 non-null      float64
#  61  mqtt.ver                    323 non-null    float64
#  62  mqtt.willmsg                0 non-null      float64
#  63  mqtt.willmsg_len            0 non-null      float64
#  64  mqtt.willtopic              0 non-null      float64
#  65  mqtt.willtopic_len          0 non-null      float64
#  66  type                        94625 non-null  object
# dtypes: float64(49), int64(6), object(12)
# memory usage: 48.4+ MB

# %%
print (df_data.isnull().sum())
# Out:
# frame.time_delta                  0
# frame.time_delta_displayed        0
# frame.time_epoch                  0
# frame.time_invalid            94625
# frame.time_relative               0
#                               ...
# mqtt.willmsg                  94625
# mqtt.willmsg_len              94625
# mqtt.willtopic                94625
# mqtt.willtopic_len            94625
# type                              0
# Length: 67, dtype: int64

# %%
df_data.drop(['frame.time_invalid','frame.coloring_rule.name', 'frame.coloring_rule.string', 'frame.comment', 'frame.comment.expert', 'frame.file_off', 'frame.incomplete', 'frame.interface_id', 'frame.interface_name', 'frame.link_nr', 'frame.md5_hash', 'mqtt.passwd', 'mqtt.passwd_len', 'mqtt.username', 'mqtt.username_len', 'mqtt.willmsg', 'mqtt.willmsg_len', 'mqtt.willtopic', 'mqtt.willtopic_len'], axis=1, inplace = True)
print (df_data.isnull().sum())
# Out:
# frame.time_delta                  0
# frame.time_delta_displayed        0
# frame.time_epoch                  0
# frame.time_relative               0
# ip.src                         1033
# ip.dst                         1033
# tcp.srcport                    6165
# tcp.dstport                    6165
# eth.src                           0
# eth.dst                           0
# frame.cap_len                     0
# frame.encap_type                  0
# frame.ignored                     0
# frame.len                         0
# frame.marked                      0
# frame.number                      0
# frame.offset_shift                0
# mqtt.clientid                 94302
# mqtt.clientid_len             94302
# mqtt.conack.flags             93855
# mqtt.conack.flags.reserved    93855
# mqtt.conack.flags.sp          93855
# mqtt.conack.val               93855
# mqtt.conflag.cleansess        94302
# mqtt.conflag.passwd           94302
# mqtt.conflag.qos              94302
# mqtt.conflag.reserved         94302
# mqtt.conflag.retain           94302
# mqtt.conflag.uname            94302
# mqtt.conflag.willflag         94302
# mqtt.conflags                 94302
# mqtt.dupflag                  56161
# mqtt.hdrflags                 55090
# mqtt.kalive                   94302
# mqtt.len                      55090
# mqtt.msg                      56892
# mqtt.msgid                    93834
# mqtt.msgtype                  55090
# mqtt.proto_len                94302
# mqtt.protoname                94302
# mqtt.qos                      56161
# mqtt.retain                   56161
# mqtt.sub.qos                  94621
# mqtt.suback.qos               94621
# mqtt.topic                    56888
# mqtt.topic_len                56157
# mqtt.ver                      94302
# type                              0
# dtype: int64

# %%
df_data.drop(['mqtt.clientid','mqtt.clientid_len', 'mqtt.conack.flags', 'mqtt.conack.flags.reserved', 'mqtt.conack.flags.sp', 'mqtt.conack.val', 'mqtt.conflag.cleansess', 'mqtt.conflag.passwd', 'mqtt.conflag.qos', 'mqtt.conflag.reserved', 'mqtt.conflag.retain', 'mqtt.conflag.uname', 'mqtt.conflag.willflag', 'mqtt.conflags', 'mqtt.kalive', 'mqtt.msgid', 'mqtt.proto_len', 'mqtt.protoname', 'mqtt.sub.qos', 'mqtt.suback.qos', 'mqtt.ver'], axis=1, inplace = True)
print (df_data.isnull().sum())
# Out:
# frame.time_delta                  0
# frame.time_delta_displayed        0
# frame.time_epoch                  0
# frame.time_relative               0
# ip.src                         1033
# ip.dst                         1033
# tcp.srcport                    6165
# tcp.dstport                    6165
# eth.src                           0
# eth.dst                           0
# frame.cap_len                     0
# frame.encap_type                  0
# frame.ignored                     0
# frame.len                         0
# frame.marked                      0
# frame.number                      0
# frame.offset_shift                0
# mqtt.dupflag                  56161
# mqtt.hdrflags                 55090
# mqtt.len                      55090
# mqtt.msg                      56892
# mqtt.msgtype                  55090
# mqtt.qos                      56161
# mqtt.retain                   56161
# mqtt.topic                    56888
# mqtt.topic_len                56157
# type                              0
# dtype: int64

# %%
le = LabelEncoder()
 
df_data['type']= le.fit_transform(df_data['type'])
df_data['frame.encap_type']= le.fit_transform(df_data['frame.encap_type'])

print(df_data['type'])
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 94620    1
# 94621    1
# 94622    1
# 94623    1
# 94624    1
# Name: type, Length: 94625, dtype: int64

# %%
df_data['ip.src'] = df_data['ip.src'].fillna(df_data['ip.src'].mode()[0])
df_data['ip.dst'] = df_data['ip.dst'].fillna(df_data['ip.dst'].mode()[0])
df_data['tcp.srcport'] = df_data['tcp.srcport'].fillna(df_data['tcp.srcport'].mean())
df_data['tcp.dstport'] = df_data['tcp.dstport'].fillna(df_data['tcp.dstport'].mean())
df_data['mqtt.dupflag'] = df_data['mqtt.dupflag'].fillna(0)
df_data['mqtt.hdrflags'] = df_data['mqtt.hdrflags'].fillna(0)
df_data['mqtt.len'] = df_data['mqtt.len'].fillna(0)
df_data['mqtt.msg'] = df_data['mqtt.msg'].fillna(0)
df_data['mqtt.msgtype'] = df_data['mqtt.msgtype'].fillna(0)
df_data['mqtt.qos'] = df_data['mqtt.qos'].fillna(0)
df_data['mqtt.retain'] = df_data['mqtt.retain'].fillna(0)
df_data['mqtt.topic'] = df_data['mqtt.topic'].fillna(0)
df_data['mqtt.topic_len'] = df_data['mqtt.topic_len'].fillna(0)

print(df_data.isna().sum())
# Out:
# frame.time_delta              0
# frame.time_delta_displayed    0
# frame.time_epoch              0
# frame.time_relative           0
# ip.src                        0
# ip.dst                        0
# tcp.srcport                   0
# tcp.dstport                   0
# eth.src                       0
# eth.dst                       0
# frame.cap_len                 0
# frame.encap_type              0
# frame.ignored                 0
# frame.len                     0
# frame.marked                  0
# frame.number                  0
# frame.offset_shift            0
# mqtt.dupflag                  0
# mqtt.hdrflags                 0
# mqtt.len                      0
# mqtt.msg                      0
# mqtt.msgtype                  0
# mqtt.qos                      0
# mqtt.retain                   0
# mqtt.topic                    0
# mqtt.topic_len                0
# type                          0
# dtype: int64

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94625 entries, 0 to 94624
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   frame.time_delta            94625 non-null  float64
#  1   frame.time_delta_displayed  94625 non-null  float64
#  2   frame.time_epoch            94625 non-null  float64
#  3   frame.time_relative         94625 non-null  float64
#  4   ip.src                      94625 non-null  object
#  5   ip.dst                      94625 non-null  object
#  6   tcp.srcport                 94625 non-null  float64
#  7   tcp.dstport                 94625 non-null  float64
#  8   eth.src                     94625 non-null  object
#  9   eth.dst                     94625 non-null  object
#  10  frame.cap_len               94625 non-null  int64
#  11  frame.encap_type            94625 non-null  int64
#  12  frame.ignored               94625 non-null  int64
#  13  frame.len                   94625 non-null  int64
#  14  frame.marked                94625 non-null  int64
#  15  frame.number                94625 non-null  int64
#  16  frame.offset_shift          94625 non-null  float64
#  17  mqtt.dupflag                94625 non-null  float64
#  18  mqtt.hdrflags               94625 non-null  object
#  19  mqtt.len                    94625 non-null  float64
#  20  mqtt.msg                    94625 non-null  object
#  21  mqtt.msgtype                94625 non-null  float64
#  22  mqtt.qos                    94625 non-null  float64
#  23  mqtt.retain                 94625 non-null  float64
#  24  mqtt.topic                  94625 non-null  object
#  25  mqtt.topic_len              94625 non-null  float64
#  26  type                        94625 non-null  int64
# dtypes: float64(13), int64(7), object(7)
# memory usage: 19.5+ MB

# %%
df_data['ip.src'] = df_data['ip.src'].apply(pd.to_numeric, errors='coerce')
df_data['ip.dst'] = df_data['ip.dst'].apply(pd.to_numeric, errors='coerce')
df_data['eth.src'] = df_data['eth.src'].apply(pd.to_numeric, errors='coerce')
df_data['eth.dst'] = df_data['eth.dst'].apply(pd.to_numeric, errors='coerce')
df_data['mqtt.hdrflags'] = df_data['mqtt.hdrflags'].apply(pd.to_numeric, errors='coerce')
df_data['mqtt.msg'] = df_data['mqtt.msg'].apply(pd.to_numeric, errors='coerce')
df_data['mqtt.topic'] = df_data['mqtt.topic'].apply(pd.to_numeric, errors='coerce')

df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94625 entries, 0 to 94624
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   frame.time_delta            94625 non-null  float64
#  1   frame.time_delta_displayed  94625 non-null  float64
#  2   frame.time_epoch            94625 non-null  float64
#  3   frame.time_relative         94625 non-null  float64
#  4   ip.src                      0 non-null      float64
#  5   ip.dst                      0 non-null      float64
#  6   tcp.srcport                 94625 non-null  float64
#  7   tcp.dstport                 94625 non-null  float64
#  8   eth.src                     0 non-null      float64
#  9   eth.dst                     0 non-null      float64
#  10  frame.cap_len               94625 non-null  int64
#  11  frame.encap_type            94625 non-null  int64
#  12  frame.ignored               94625 non-null  int64
#  13  frame.len                   94625 non-null  int64
#  14  frame.marked                94625 non-null  int64
#  15  frame.number                94625 non-null  int64
#  16  frame.offset_shift          94625 non-null  float64
#  17  mqtt.dupflag                94625 non-null  float64
#  18  mqtt.hdrflags               55090 non-null  float64
#  19  mqtt.len                    94625 non-null  float64
#  20  mqtt.msg                    57132 non-null  float64
#  21  mqtt.msgtype                94625 non-null  float64
#  22  mqtt.qos                    94625 non-null  float64
#  23  mqtt.retain                 94625 non-null  float64
#  24  mqtt.topic                  56888 non-null  float64
#  25  mqtt.topic_len              94625 non-null  float64
#  26  type                        94625 non-null  int64
# dtypes: float64(20), int64(7)
# memory usage: 19.5 MB

# %%
print(df_data.isna().sum())
# Out:
# frame.time_delta                  0
# frame.time_delta_displayed        0
# frame.time_epoch                  0
# frame.time_relative               0
# ip.src                        94625
# ip.dst                        94625
# tcp.srcport                       0
# tcp.dstport                       0
# eth.src                       94625
# eth.dst                       94625
# frame.cap_len                     0
# frame.encap_type                  0
# frame.ignored                     0
# frame.len                         0
# frame.marked                      0
# frame.number                      0
# frame.offset_shift                0
# mqtt.dupflag                      0
# mqtt.hdrflags                 39535
# mqtt.len                          0
# mqtt.msg                      37493
# mqtt.msgtype                      0
# mqtt.qos                          0
# mqtt.retain                       0
# mqtt.topic                    37737
# mqtt.topic_len                    0
# type                              0
# dtype: int64

# %%
df_data.drop(['ip.src', 'ip.dst', 'eth.src', 'eth.dst'], axis=1, inplace = True)
print(df_data.isna().sum())
# Out:
# frame.time_delta                  0
# frame.time_delta_displayed        0
# frame.time_epoch                  0
# frame.time_relative               0
# tcp.srcport                       0
# tcp.dstport                       0
# frame.cap_len                     0
# frame.encap_type                  0
# frame.ignored                     0
# frame.len                         0
# frame.marked                      0
# frame.number                      0
# frame.offset_shift                0
# mqtt.dupflag                      0
# mqtt.hdrflags                 39535
# mqtt.len                          0
# mqtt.msg                      37493
# mqtt.msgtype                      0
# mqtt.qos                          0
# mqtt.retain                       0
# mqtt.topic                    37737
# mqtt.topic_len                    0
# type                              0
# dtype: int64

# %%
df_data['mqtt.hdrflags'] = df_data['mqtt.hdrflags'].fillna(df_data['mqtt.hdrflags'].mean())
df_data['mqtt.msg'] = df_data['mqtt.msg'].fillna(df_data['mqtt.msg'].mean())
df_data['mqtt.topic'] = df_data['mqtt.topic'].fillna(df_data['mqtt.topic'].mean())

print(df_data.isna().sum())
# Out:
# frame.time_delta              0
# frame.time_delta_displayed    0
# frame.time_epoch              0
# frame.time_relative           0
# tcp.srcport                   0
# tcp.dstport                   0
# frame.cap_len                 0
# frame.encap_type              0
# frame.ignored                 0
# frame.len                     0
# frame.marked                  0
# frame.number                  0
# frame.offset_shift            0
# mqtt.dupflag                  0
# mqtt.hdrflags                 0
# mqtt.len                      0
# mqtt.msg                      0
# mqtt.msgtype                  0
# mqtt.qos                      0
# mqtt.retain                   0
# mqtt.topic                    0
# mqtt.topic_len                0
# type                          0
# dtype: int64

# %%
df_data
# Out:
#        frame.time_delta  frame.time_delta_displayed  ...  mqtt.topic_len  type
# 0              0.000000                    0.000000  ...             0.0     1
# 1              0.001922                    0.001922  ...             0.0     1
# 2              0.001010                    0.001010  ...             0.0     1
# 3              0.008597                    0.008597  ...             0.0     1
# 4              0.002925                    0.002925  ...             0.0     1
# ...                 ...                         ...  ...             ...   ...
# 94620          0.000097                    0.000097  ...             0.0     1
# 94621          0.001754                    0.001754  ...             0.0     1
# 94622          0.001133                    0.001133  ...             0.0     1
# 94623          0.000074                    0.000074  ...             0.0     1
# 94624          0.057908                    0.057908  ...             0.0     1
#
# [94625 rows x 23 columns]

# %%
x = df_data.drop(['type'], axis = 1)
x.head()
# Out:
#    frame.time_delta  frame.time_delta_displayed  ...  mqtt.topic  mqtt.topic_len
# 0          0.000000                    0.000000  ...         0.0             0.0
# 1          0.001922                    0.001922  ...         0.0             0.0
# 2          0.001010                    0.001010  ...         0.0             0.0
# 3          0.008597                    0.008597  ...         0.0             0.0
# 4          0.002925                    0.002925  ...         0.0             0.0
#
# [5 rows x 22 columns]

# %%
sc_X = StandardScaler()
x = sc_X.fit_transform(x)

# %%
y = df_data['type']
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: type, dtype: int64

# %%
from collections import Counter
counter = Counter(y)
print(counter)
# Out:
# Counter({1: 49111, 0: 45514})

# %%
from imblearn.over_sampling import SMOTE
# transform the dataset
oversample = SMOTE()
x, y = oversample.fit_resample(x, y)

# %%
from collections import Counter
counter = Counter(y)
print(counter)
# Out:
# Counter({1: 49111, 0: 49111})

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state= 100)

# %%
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
model = Sequential()
model.add(GRU(128, input_shape=(X_train.shape[1], X_train.shape[2]) ,return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.summary()
model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])
model.fit(X_train, y_train, epochs=50, batch_size=72, verbose=1, validation_data=(X_test, y_test), shuffle=False)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 128)               58368
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 58,497
# Trainable params: 58,497
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1092/1092 [==============================] - 10s 7ms/step - loss: 0.1710 - accuracy: 0.9371 - val_loss: 0.1180 - val_accuracy: 0.9461
# Epoch 2/50
# 1092/1092 [==============================] - 9s 8ms/step - loss: 0.1206 - accuracy: 0.9541 - val_loss: 0.1086 - val_accuracy: 0.9610
# Epoch 3/50
# 1092/1092 [==============================] - 9s 8ms/step - loss: 0.1149 - accuracy: 0.9564 - val_loss: 0.1041 - val_accuracy: 0.9622
# Epoch 4/50
# 1092/1092 [==============================] - 9s 8ms/step - loss: 0.1104 - accuracy: 0.9586 - val_loss: 0.0999 - val_accuracy: 0.9650
# Epoch 5/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.1068 - accuracy: 0.9606 - val_loss: 0.0965 - val_accuracy: 0.9651
# Epoch 6/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.1041 - accuracy: 0.9629 - val_loss: 0.0918 - val_accuracy: 0.9710
# Epoch 7/50
# 1092/1092 [==============================] - 9s 8ms/step - loss: 0.0990 - accuracy: 0.9655 - val_loss: 0.0851 - val_accuracy: 0.9735
# Epoch 8/50
# 1092/1092 [==============================] - 9s 8ms/step - loss: 0.0911 - accuracy: 0.9684 - val_loss: 0.0765 - val_accuracy: 0.9744
# Epoch 9/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0828 - accuracy: 0.9708 - val_loss: 0.0690 - val_accuracy: 0.9768
# Epoch 10/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0774 - accuracy: 0.9726 - val_loss: 0.0643 - val_accuracy: 0.9783
# Epoch 11/50
# 1092/1092 [==============================] - 7s 6ms/step - loss: 0.0729 - accuracy: 0.9738 - val_loss: 0.0610 - val_accuracy: 0.9794
# Epoch 12/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0694 - accuracy: 0.9747 - val_loss: 0.0586 - val_accuracy: 0.9792
# Epoch 13/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0669 - accuracy: 0.9754 - val_loss: 0.0573 - val_accuracy: 0.9805
# Epoch 14/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0645 - accuracy: 0.9767 - val_loss: 0.0554 - val_accuracy: 0.9806
# Epoch 15/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0627 - accuracy: 0.9770 - val_loss: 0.0521 - val_accuracy: 0.9816
# Epoch 16/50
# 1092/1092 [==============================] - 5s 5ms/step - loss: 0.0618 - accuracy: 0.9777 - val_loss: 0.0508 - val_accuracy: 0.9812
# Epoch 17/50
# 1092/1092 [==============================] - 7s 6ms/step - loss: 0.0599 - accuracy: 0.9783 - val_loss: 0.0494 - val_accuracy: 0.9806
# Epoch 18/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0582 - accuracy: 0.9795 - val_loss: 0.0476 - val_accuracy: 0.9822
# Epoch 19/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0567 - accuracy: 0.9798 - val_loss: 0.0459 - val_accuracy: 0.9854
# Epoch 20/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0552 - accuracy: 0.9808 - val_loss: 0.0434 - val_accuracy: 0.9859
# Epoch 21/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0521 - accuracy: 0.9822 - val_loss: 0.0415 - val_accuracy: 0.9873
# Epoch 22/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0498 - accuracy: 0.9834 - val_loss: 0.0388 - val_accuracy: 0.9881
# Epoch 23/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0483 - accuracy: 0.9837 - val_loss: 0.0371 - val_accuracy: 0.9886
# Epoch 24/50
# 1092/1092 [==============================] - 7s 6ms/step - loss: 0.0463 - accuracy: 0.9848 - val_loss: 0.0348 - val_accuracy: 0.9889
# Epoch 25/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0438 - accuracy: 0.9853 - val_loss: 0.0323 - val_accuracy: 0.9891
# Epoch 26/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0419 - accuracy: 0.9853 - val_loss: 0.0299 - val_accuracy: 0.9908
# Epoch 27/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0392 - accuracy: 0.9863 - val_loss: 0.0281 - val_accuracy: 0.9917
# Epoch 28/50
# 1092/1092 [==============================] - 7s 7ms/step - loss: 0.0366 - accuracy: 0.9871 - val_loss: 0.0260 - val_accuracy: 0.9940
# Epoch 29/50
# 1092/1092 [==============================] - 7s 6ms/step - loss: 0.0345 - accuracy: 0.9879 - val_loss: 0.0238 - val_accuracy: 0.9938
# Epoch 30/50
# 1092/1092 [==============================] - 7s 7ms/step - loss: 0.0331 - accuracy: 0.9886 - val_loss: 0.0227 - val_accuracy: 0.9931
# Epoch 31/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0311 - accuracy: 0.9894 - val_loss: 0.0207 - val_accuracy: 0.9940
# Epoch 32/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0300 - accuracy: 0.9900 - val_loss: 0.0195 - val_accuracy: 0.9948
# Epoch 33/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0290 - accuracy: 0.9899 - val_loss: 0.0183 - val_accuracy: 0.9964
# Epoch 34/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0275 - accuracy: 0.9908 - val_loss: 0.0183 - val_accuracy: 0.9976
# Epoch 35/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0266 - accuracy: 0.9909 - val_loss: 0.0166 - val_accuracy: 0.9958
# Epoch 36/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0256 - accuracy: 0.9910 - val_loss: 0.0150 - val_accuracy: 0.9977
# Epoch 37/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0249 - accuracy: 0.9918 - val_loss: 0.0153 - val_accuracy: 0.9976
# Epoch 38/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0240 - accuracy: 0.9921 - val_loss: 0.0151 - val_accuracy: 0.9975
# Epoch 39/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0227 - accuracy: 0.9919 - val_loss: 0.0139 - val_accuracy: 0.9976
# Epoch 40/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0223 - accuracy: 0.9927 - val_loss: 0.0126 - val_accuracy: 0.9981
# Epoch 41/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0216 - accuracy: 0.9930 - val_loss: 0.0127 - val_accuracy: 0.9978
# Epoch 42/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0199 - accuracy: 0.9932 - val_loss: 0.0119 - val_accuracy: 0.9981
# Epoch 43/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0202 - accuracy: 0.9935 - val_loss: 0.0123 - val_accuracy: 0.9978
# Epoch 44/50
# 1092/1092 [==============================] - 6s 6ms/step - loss: 0.0187 - accuracy: 0.9940 - val_loss: 0.0127 - val_accuracy: 0.9977
# Epoch 45/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0186 - accuracy: 0.9935 - val_loss: 0.0114 - val_accuracy: 0.9979
# Epoch 46/50
# 1092/1092 [==============================] - 9s 8ms/step - loss: 0.0178 - accuracy: 0.9941 - val_loss: 0.0105 - val_accuracy: 0.9984
# Epoch 47/50
# 1092/1092 [==============================] - 7s 6ms/step - loss: 0.0169 - accuracy: 0.9945 - val_loss: 0.0104 - val_accuracy: 0.9981
# Epoch 48/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0170 - accuracy: 0.9948 - val_loss: 0.0101 - val_accuracy: 0.9981
# Epoch 49/50
# 1092/1092 [==============================] - 6s 5ms/step - loss: 0.0165 - accuracy: 0.9949 - val_loss: 0.0098 - val_accuracy: 0.9982
# Epoch 50/50
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.0162 - accuracy: 0.9948 - val_loss: 0.0095 - val_accuracy: 0.9983

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(y_pred)
# Out:
# [[False]
#  [False]
#  [ True]
#  ...
#  [False]
#  [False]
#  [False]]

# %%
y_pred = y_pred[:, 0]
conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred)
print('Recall: %f' % recall)
# Out:
# Accuracy: 0.998269
# Precision: 0.999084
# Recall: 0.997459
